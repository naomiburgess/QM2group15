# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-df77e611-3f8f-4b26-b1bb-24789df3df5e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df77e611-3f8f-4b26-b1bb-24789df3df5e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ward_profiles.csv to ward_profiles (1).csv

# %%
df = pd.read_csv('ward_profiles.csv', encoding='latin1')
print("Size of dataset is : ", df.shape)
df
# Out:
# Size of dataset is :  (661, 67)
#                               ï»¿Ward name  ... Turnout at Mayoral election - 2012
# 0                           City of London  ...                              48.50
# 1             Barking and Dagenham - Abbey  ...                              25.70
# 2            Barking and Dagenham - Alibon  ...                              20.30
# 3         Barking and Dagenham - Becontree  ...                              22.50
# 4    Barking and Dagenham - Chadwell Heath  ...                              25.30
# ..                                     ...  ...                                ...
# 656                             Wandsworth  ...                              40.70
# 657                            Westminster  ...                              37.70
# 658                                 London  ...                              34.20
# 659                                England  ...                                NaN
# 660                                Source:  ...                      London Elects
#
# [661 rows x 67 columns]

# %%
x=625 # here we use a wider dataset, tweaking on the codes team member Laudomia presented.
y=662 
df.loc[x:y]
df.loc[x:y].index
df.drop(df.loc[x:y].index, inplace=True)
df
# Out:
#                               ï»¿Ward name  ... Turnout at Mayoral election - 2012
# 0                           City of London  ...                              48.50
# 1             Barking and Dagenham - Abbey  ...                              25.70
# 2            Barking and Dagenham - Alibon  ...                              20.30
# 3         Barking and Dagenham - Becontree  ...                              22.50
# 4    Barking and Dagenham - Chadwell Heath  ...                              25.30
# ..                                     ...  ...                                ...
# 620                Westminster - Tachbrook  ...                              40.20
# 621           Westminster - Vincent Square  ...                              37.80
# 622                  Westminster - Warwick  ...                              36.80
# 623               Westminster - Westbourne  ...                              29.60
# 624                 Westminster - West End  ...                              29.70
#
# [625 rows x 67 columns]

# %%
df_all_wards=df[['ï»¿Ward name', 'Population density (persons per sq km) - 2013', '% All Working-age (16-64) - 2015', 'Employment rate (16-64) - 2011', 'Median Household income estimate (2012/13)', 'Crime rate - 2014/15']]
df_all_wards= df_all_wards.rename(columns={'ï»¿Ward name': 'Ward name'})
df_all_wards
# Out:
#                                  Ward name  ... Crime rate - 2014/15
# 0                           City of London  ...               656.40
# 1             Barking and Dagenham - Abbey  ...               138.10
# 2            Barking and Dagenham - Alibon  ...                73.60
# 3         Barking and Dagenham - Becontree  ...                79.90
# 4    Barking and Dagenham - Chadwell Heath  ...                76.10
# ..                                     ...  ...                  ...
# 620                Westminster - Tachbrook  ...                57.70
# 621           Westminster - Vincent Square  ...                82.40
# 622                  Westminster - Warwick  ...               138.10
# 623               Westminster - Westbourne  ...                75.50
# 624                 Westminster - West End  ...              1212.10
#
# [625 rows x 6 columns]

# %%
#Need to get rid of the commas, or later on will not be able to convert to flaot
df_all_wards['Population density (persons per sq km) - 2013'] = df_all_wards['Population density (persons per sq km) - 2013'].str.replace(',', '')
df_all_wards['Median Household income estimate (2012/13)'] = df_all_wards['Median Household income estimate (2012/13)'].str.replace(',', '')
df_all_wards
# Out:
#                                  Ward name  ... Crime rate - 2014/15
# 0                           City of London  ...               656.40
# 1             Barking and Dagenham - Abbey  ...               138.10
# 2            Barking and Dagenham - Alibon  ...                73.60
# 3         Barking and Dagenham - Becontree  ...                79.90
# 4    Barking and Dagenham - Chadwell Heath  ...                76.10
# ..                                     ...  ...                  ...
# 620                Westminster - Tachbrook  ...                57.70
# 621           Westminster - Vincent Square  ...                82.40
# 622                  Westminster - Warwick  ...               138.10
# 623               Westminster - Westbourne  ...                75.50
# 624                 Westminster - West End  ...              1212.10
#
# [625 rows x 6 columns]

# %%
import sklearn
from sklearn import linear_model
X = df_all_wards[['Population density (persons per sq km) - 2013', '% All Working-age (16-64) - 2015', 'Employment rate (16-64) - 2011', 'Median Household income estimate (2012/13)']] 
# here we have 4 variables for multiple regression. 
# being population density, percentage of working age people, employment rate, and median household income
Y = df_all_wards['Crime rate - 2014/15']
# the years from which the data is captured are different, which will partially affect our accuracy.

# %%
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -258.7341777800802
# Coefficients:
#  [-4.65108719e-03  8.06390598e+00 -3.65745577e+00  2.10602532e-03]

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y.astype(float),X.astype(float)).fit()
 
print_model = model.summary()
print(print_model)
#R square, coefficient, t value, P>t
#recording of last workshop, scatter graph of each variable
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Crime rate - 2014/15   R-squared:                       0.256
# Model:                              OLS   Adj. R-squared:                  0.251
# Method:                   Least Squares   F-statistic:                     53.22
# Date:                  Sun, 03 Jan 2021   Prob (F-statistic):           1.45e-38
# Time:                          18:21:45   Log-Likelihood:                -3487.6
# No. Observations:                   625   AIC:                             6985.
# Df Residuals:                       620   BIC:                             7007.
# Df Model:                             4
# Covariance Type:              nonrobust
# =================================================================================================================
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# const                                          -258.7342     50.118     -5.163      0.000    -357.156    -160.313
# Population density (persons per sq km) - 2013    -0.0047      0.001     -6.352      0.000      -0.006      -0.003
# % All Working-age (16-64) - 2015                  8.0639      0.678     11.894      0.000       6.733       9.395
# Employment rate (16-64) - 2011                   -3.6575      0.538     -6.798      0.000      -4.714      -2.601
# Median Household income estimate (2012/13)        0.0021      0.000      4.645      0.000       0.001       0.003
# ==============================================================================
# Omnibus:                     1000.970   Durbin-Watson:                   1.507
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           427906.743
# Skew:                           9.346   Prob(JB):                         0.00
# Kurtosis:                     129.816   Cond. No.                     7.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
