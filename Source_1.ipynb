# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
df = pd.read_csv('ward_profiles.csv', encoding='latin1')
print("Size of dataset is : ", df.shape)
df
# Out:
# Size of dataset is :  (660, 67)
#                                  Ward name  ... Turnout at Mayoral election - 2012
# 0                           City of London  ...                               48.5
# 1             Barking and Dagenham - Abbey  ...                               25.7
# 2            Barking and Dagenham - Alibon  ...                               20.3
# 3         Barking and Dagenham - Becontree  ...                               22.5
# 4    Barking and Dagenham - Chadwell Heath  ...                               25.3
# ..                                     ...  ...                                ...
# 655                         Waltham Forest  ...                               37.6
# 656                             Wandsworth  ...                               40.7
# 657                            Westminster  ...                               37.7
# 658                                 London  ...                               34.2
# ...

# %%
x=0 # could change x and y to a start and end date
y=102 
df.loc[x:y]
df.loc[x:y].index
df.drop(df.loc[x:y].index, inplace=True)
df
# Out:
#                                    Ward name  ... Turnout at Mayoral election - 2012
# 103                         Camden - Belsize  ...                               36.2
# 104                      Camden - Bloomsbury  ...                               33.2
# 105  Camden - Camden Town with Primrose Hill  ...                               41.6
# 106                      Camden - Cantelowes  ...                               37.3
# 107                   Camden - Fortune Green  ...                               37.8
# ..                                       ...  ...                                ...
# 655                           Waltham Forest  ...                               37.6
# 656                               Wandsworth  ...                               40.7
# 657                              Westminster  ...                               37.7
# 658                                   London  ...                               34.2
# ...

# %%
x=121 # could change x and y to a start and end date
y=356 
df.loc[x:y]
df.loc[x:y].index
df.drop(df.loc[x:y].index, inplace=True)
df
# Out:
#                                    Ward name  ... Turnout at Mayoral election - 2012
# 103                         Camden - Belsize  ...                               36.2
# 104                      Camden - Bloomsbury  ...                               33.2
# 105  Camden - Camden Town with Primrose Hill  ...                               41.6
# 106                      Camden - Cantelowes  ...                               37.3
# 107                   Camden - Fortune Green  ...                               37.8
# ..                                       ...  ...                                ...
# 655                           Waltham Forest  ...                               37.6
# 656                               Wandsworth  ...                               40.7
# 657                              Westminster  ...                               37.7
# 658                                   London  ...                               34.2
# ...

# %%
x=375 # could change x and y to a start and end date
y=660 
df.loc[x:y]
df.loc[x:y].index
df.drop(df.loc[x:y].index, inplace=True)
df
# Out:
#                                    Ward name  ... Turnout at Mayoral election - 2012
# 103                         Camden - Belsize  ...                               36.2
# 104                      Camden - Bloomsbury  ...                               33.2
# 105  Camden - Camden Town with Primrose Hill  ...                               41.6
# 106                      Camden - Cantelowes  ...                               37.3
# 107                   Camden - Fortune Green  ...                               37.8
# 108           Camden - Frognal and Fitzjohns  ...                               34.4
# 109                      Camden - Gospel Oak  ...                               40.3
# 110                  Camden - Hampstead Town  ...                               40.8
# 111                      Camden - Haverstock  ...                               38.3
# 112                        Camden - Highgate  ...                               46.0
# ...

# %%
df1 = df[["Ward name","Area - Square Kilometres", "Population - 2015", "Working-age (16-64) - 2015", "Employment rate (16-64) - 2011", "Median Household income estimate (2012/13)", "Average Public Transport Accessibility score - 2014"]]
df1
# Out:
#                                    Ward name  ...  Average Public Transport Accessibility score - 2014
# 103                         Camden - Belsize  ...                                                4.2
# 104                      Camden - Bloomsbury  ...                                                8.0
# 105  Camden - Camden Town with Primrose Hill  ...                                                5.4
# 106                      Camden - Cantelowes  ...                                                4.9
# 107                   Camden - Fortune Green  ...                                                4.8
# 108           Camden - Frognal and Fitzjohns  ...                                                4.8
# 109                      Camden - Gospel Oak  ...                                                4.1
# 110                  Camden - Hampstead Town  ...                                                4.0
# ...
