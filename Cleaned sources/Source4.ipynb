# %% [markdown]
# <a href="https://colab.research.google.com/github/naomiburgess/QM2group15/blob/main/Source4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
df = pd.read_csv('On_Street_Crime_In_Camden_Map.csv', encoding='latin1')
print("Size of dataset is : ", df.shape)
df
# Out:
# Size of dataset is :  (210979, 20)
#                             Category  ...                Location
# 0                        Other theft  ...    (51.5318, -0.123189)
# 1              Anti-social behaviour  ...  (51.528169, -0.131558)
# 2              Theft from the person  ...  (51.542741, -0.174124)
# 3              Anti-social behaviour  ...  (51.529611, -0.121652)
# 4                              Drugs  ...  (51.565544, -0.149851)
# ...                              ...  ...                     ...
# 210974                   Other theft  ...  (51.539189, -0.142008)
# 210975  Violence and sexual offences  ...  (51.524772, -0.133427)
# 210976                  Public order  ...  (51.564519, -0.142505)
# 210977                   Other theft  ...  (51.529117, -0.126199)
# 210978                 Bicycle theft  ...  (51.517208, -0.117002)
#
# [210979 rows x 20 columns]

# %%
df = df[df.Category != "Public order"]
df = df[df.Category != "Violence and sexual offences"]
df = df[df.Category != "Drugs"]
df = df[df.Category != "Anti-social behaviour"]
df = df[df.Category != "Vehicle crime"]
df = df[df.Category != "Possession of weapons"]
df = df[df.Category != "Other theft"]
df = df[df.Category != "Burglary"]
df = df[df.Category != "Robbery"]
df = df[df.Category != "Shoplifting"]
df = df[df.Category != "Criminal damage and arson"]

df
# Out:
#                      Category  Street ID  ... Last Uploaded                Location
# 2       Theft from the person     965233  ...    05/05/2016  (51.542741, -0.174124)
# 8       Theft from the person     965140  ...    11/07/2018   (51.541352, -0.14629)
# 15      Theft from the person     965122  ...    11/07/2018   (51.54288, -0.147425)
# 18      Theft from the person     965104  ...    11/07/2018  (51.540012, -0.151997)
# 21      Theft from the person     965082  ...    03/11/2017  (51.544104, -0.149754)
# ...                       ...        ...  ...           ...                     ...
# 210963  Theft from the person     967813  ...    20/06/2017  (51.548656, -0.152685)
# 210969          Bicycle theft     961015  ...    13/04/2018  (51.521116, -0.117346)
# 210970  Theft from the person     960941  ...    05/06/2017  (51.526573, -0.125078)
# 210972  Theft from the person     965125  ...    05/05/2016   (51.541489, -0.14588)
# ...

# %%
df.drop(columns=['Outcome Category', 'Context', 'Outcome Date', 'ID', 'Service', 'Location Subtype', 'Persistent ID', 'Ward Code', 'Spatial Accuracy', 'Last Uploaded'])
# Out:
#                      Category  Street ID  ...   Latitude                Location
# 2       Theft from the person     965233  ...  51.542741  (51.542741, -0.174124)
# 8       Theft from the person     965140  ...  51.541352   (51.541352, -0.14629)
# 15      Theft from the person     965122  ...  51.542880   (51.54288, -0.147425)
# 18      Theft from the person     965104  ...  51.540012  (51.540012, -0.151997)
# 21      Theft from the person     965082  ...  51.544104  (51.544104, -0.149754)
# ...                       ...        ...  ...        ...                     ...
# 210963  Theft from the person     967813  ...  51.548656  (51.548656, -0.152685)
# 210969          Bicycle theft     961015  ...  51.521116  (51.521116, -0.117346)
# 210970  Theft from the person     960941  ...  51.526573  (51.526573, -0.125078)
# 210972  Theft from the person     965125  ...  51.541489   (51.541489, -0.14588)
# 210978          Bicycle theft     956249  ...  51.517208  (51.517208, -0.117002)
#
# ...
