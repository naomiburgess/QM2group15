# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
df = pd.read_csv('ward-profiles-excel-version.csv', encoding='latin1')
print("Size of dataset is : ", df.shape)
df
# Out:
# Size of dataset is :  (660, 67)
#                                  Ward name  ... Turnout at Mayoral election - 2012
# 0                           City of London  ...                               48.5
# 1             Barking and Dagenham - Abbey  ...                               25.7
# 2            Barking and Dagenham - Alibon  ...                               20.3
# 3         Barking and Dagenham - Becontree  ...                               22.5
# 4    Barking and Dagenham - Chadwell Heath  ...                               25.3
# ..                                     ...  ...                                ...
# 655                         Waltham Forest  ...                               37.6
# 656                             Wandsworth  ...                               40.7
# 657                            Westminster  ...                               37.7
# 658                                 London  ...                               34.2
# ...

# %%
x=0 # could change x and y to a start and end date
y=102 
df.loc[x:y]
df.loc[x:y].index
df.drop(df.loc[x:y].index, inplace=True)
df
# Out:
#                                    Ward name  ... Turnout at Mayoral election - 2012
# 103                         Camden - Belsize  ...                               36.2
# 104                      Camden - Bloomsbury  ...                               33.2
# 105  Camden - Camden Town with Primrose Hill  ...                               41.6
# 106                      Camden - Cantelowes  ...                               37.3
# 107                   Camden - Fortune Green  ...                               37.8
# ..                                       ...  ...                                ...
# 655                           Waltham Forest  ...                               37.6
# 656                               Wandsworth  ...                               40.7
# 657                              Westminster  ...                               37.7
# 658                                   London  ...                               34.2
# ...

# %%
x=121 # could change x and y to a start and end date
y=356 
df.loc[x:y]
df.loc[x:y].index
df.drop(df.loc[x:y].index, inplace=True)
df
# Out:
#                                    Ward name  ... Turnout at Mayoral election - 2012
# 103                         Camden - Belsize  ...                               36.2
# 104                      Camden - Bloomsbury  ...                               33.2
# 105  Camden - Camden Town with Primrose Hill  ...                               41.6
# 106                      Camden - Cantelowes  ...                               37.3
# 107                   Camden - Fortune Green  ...                               37.8
# ..                                       ...  ...                                ...
# 655                           Waltham Forest  ...                               37.6
# 656                               Wandsworth  ...                               40.7
# 657                              Westminster  ...                               37.7
# 658                                   London  ...                               34.2
# ...

# %%
x=375 # could change x and y to a start and end date
y=660 
df.loc[x:y]
df.loc[x:y].index
df.drop(df.loc[x:y].index, inplace=True)
df
# Out:
#                                    Ward name  ... Turnout at Mayoral election - 2012
# 103                         Camden - Belsize  ...                               36.2
# 104                      Camden - Bloomsbury  ...                               33.2
# 105  Camden - Camden Town with Primrose Hill  ...                               41.6
# 106                      Camden - Cantelowes  ...                               37.3
# 107                   Camden - Fortune Green  ...                               37.8
# 108           Camden - Frognal and Fitzjohns  ...                               34.4
# 109                      Camden - Gospel Oak  ...                               40.3
# 110                  Camden - Hampstead Town  ...                               40.8
# 111                      Camden - Haverstock  ...                               38.3
# 112                        Camden - Highgate  ...                               46.0
# ...

# %%
x=100 # could change x and y to a start and end date
y=120 
df.loc[x:y]
df.loc[x:y].index
df.drop(df.loc[x:y].index, inplace=True)
df
# Out:
#                                    Ward name  ... Turnout at Mayoral election - 2012
# 357        Kensington and Chelsea - Abingdon  ...                               31.7
# 358        Kensington and Chelsea - Brompton  ...                               27.7
# 359         Kensington and Chelsea - Campden  ...                               33.2
# 360        Kensington and Chelsea - Colville  ...                               31.8
# 361      Kensington and Chelsea - Courtfield  ...                               24.9
# 362        Kensington and Chelsea - Cremorne  ...                               35.1
# 363    Kensington and Chelsea - Earl's Court  ...                               27.9
# 364        Kensington and Chelsea - Golborne  ...                               29.3
# 365       Kensington and Chelsea - Hans Town  ...                               27.7
# 366         Kensington and Chelsea - Holland  ...                               31.8
# ...

# %%
plt.scatter(df['Population density (persons per sq km) - 2013'], df['Crime rate - 2014/15'], color='blue')
plt.title('Population density VS Crime rate', fontsize=14)
plt.xlabel('Population density (persons per sq km) - 2013', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['% All Working-age (16-64) - 2015'], df['Crime rate - 2014/15'], color='blue')
plt.title('Working Age VS Crime rate', fontsize=14)
plt.xlabel('% All Working-age (16-64) - 2015', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['Employment rate (16-64) - 2011'], df['Crime rate - 2014/15'], color='blue')
plt.title('Employment rate VS Crime rate', fontsize=14)
plt.xlabel('Employment rate (16-64) - 2011', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['Median Household income estimate (2012/13)'], df['Crime rate - 2014/15'], color='blue')
plt.title('Median Household income estimate VS Crime rate', fontsize=14)
plt.xlabel('Median Household income estimate (2012/13)', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['Population density (persons per sq km) - 2013'], df['Crime rate - 2014/15'], color='blue')
plt.title('Population density VS Crime rate', fontsize=14)
plt.xlabel('Population density (persons per sq km) - 2013', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['% Not Born in UK - 2011'], df['Crime rate - 2014/15'], color='blue')
plt.title('% Not Born in UK VS Crime rate', fontsize=14)
plt.xlabel('% Not Born in UK - 2011', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['% English is First Language of no one in household - 2011'], df['Crime rate - 2014/15'], color='blue')
plt.title('% English is First Language of no one in household VS Crime rate', fontsize=14)
plt.xlabel('P% English is First Language of no one in household - 2011', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['Median House Price (£) - 2014'], df['Crime rate - 2014/15'], color='blue')
plt.title('Median House Price (£) VS Crime rate', fontsize=14)
plt.xlabel('Median House Price (£) - 2014', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['Claimant Rate of Housing Benefit (2015)'], df['Crime rate - 2014/15'], color='blue')
plt.title('Claimant Rate of Housing Benefit VS Crime rate', fontsize=14)
plt.xlabel('Claimant Rate of Housing Benefit (2015)', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['Claimant Rate of Employment Support Allowance - 2014'], df['Crime rate - 2014/15'], color='blue')
plt.title('Claimant Rate of Employment Support Allowance VS Crime rate', fontsize=14)
plt.xlabel('Claimant Rate of Employment Support Allowance - 2014', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['% with no qualifications - 2011'], df['Crime rate - 2014/15'], color='blue')
plt.title('% with no qualifications - 2011', fontsize=14)
plt.xlabel('% with no qualifications - 2011', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['% with Level 4 qualifications and above - 2011'], df['Crime rate - 2014/15'], color='blue')
plt.title('% with Level 4 qualifications and above VS Crime Rate', fontsize=14)
plt.xlabel('% with Level 4 qualifications and above - 2011', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()

# %%
plt.scatter(df['A-Level Average Point Score Per Student - 2013/14'], df['Crime rate - 2014/15'], color='blue')
plt.title('A-Level Average Point Score Per Student VS Crime Rate', fontsize=14)
plt.xlabel('A-Level Average Point Score Per Student - 2013/14', fontsize=14)
plt.ylabel('Crime rate - 2014/15', fontsize=14)
plt.show()
